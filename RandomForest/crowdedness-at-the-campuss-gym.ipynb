# %% [markdown]
# <a href="https://www.kaggle.com/code/kberkek00/crowdedness-at-the-campuss-gym?scriptVersionId=287492794" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('data.csv')

# %%
df.head()
# Out:
#    number_people                       date  timestamp  day_of_week  \
# 0             37  2015-08-14 17:00:11-07:00      61211            4
# 1             45  2015-08-14 17:20:14-07:00      62414            4
# 2             40  2015-08-14 17:30:15-07:00      63015            4
# 3             44  2015-08-14 17:40:16-07:00      63616            4
# 4             45  2015-08-14 17:50:17-07:00      64217            4
#
#    is_weekend  is_holiday  temperature  is_start_of_semester  \
# 0           0           0        71.76                     0
# 1           0           0        71.76                     0
# 2           0           0        71.76                     0
# 3           0           0        71.76                     0
# 4           0           0        71.76                     0
#
#    is_during_semester  month  hour
# 0                   0      8    17
# 1                   0      8    17
# 2                   0      8    17
# 3                   0      8    17
# ...

# %%
df.columns
# Out:
# Index(['number_people', 'date', 'timestamp', 'day_of_week', 'is_weekend',
#        'is_holiday', 'temperature', 'is_start_of_semester',
#        'is_during_semester', 'month', 'hour'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 62184 entries, 0 to 62183
# Data columns (total 11 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   number_people         62184 non-null  int64
#  1   date                  62184 non-null  object
#  2   timestamp             62184 non-null  int64
#  3   day_of_week           62184 non-null  int64
#  4   is_weekend            62184 non-null  int64
#  5   is_holiday            62184 non-null  int64
#  6   temperature           62184 non-null  float64
#  7   is_start_of_semester  62184 non-null  int64
#  8   is_during_semester    62184 non-null  int64
#  9   month                 62184 non-null  int64
#  10  hour                  62184 non-null  int64
# dtypes: float64(1), int64(9), object(1)
# memory usage: 5.2+ MB

# %%
df.isnull().sum()
# Out:
# number_people           0
# date                    0
# timestamp               0
# day_of_week             0
# is_weekend              0
# is_holiday              0
# temperature             0
# is_start_of_semester    0
# is_during_semester      0
# month                   0
# hour                    0
# dtype: int64

# %%
df.describe()
# Out:
#        number_people     timestamp   day_of_week    is_weekend    is_holiday  \
# count   62184.000000  62184.000000  62184.000000  62184.000000  62184.000000
# mean       29.072543  45799.437958      2.982504      0.282870      0.002573
# std        22.689026  24211.275891      1.996825      0.450398      0.050660
# min         0.000000      0.000000      0.000000      0.000000      0.000000
# 25%         9.000000  26624.000000      1.000000      0.000000      0.000000
# 50%        28.000000  46522.500000      3.000000      0.000000      0.000000
# 75%        43.000000  66612.000000      5.000000      1.000000      0.000000
# max       145.000000  86399.000000      6.000000      1.000000      1.000000
#
#         temperature  is_start_of_semester  is_during_semester         month  \
# count  62184.000000          62184.000000        62184.000000  62184.000000
# mean      58.557108              0.078831            0.660218      7.439824
# ...

# %%
df["date"]
# Out:
# 0        2015-08-14 17:00:11-07:00
# 1        2015-08-14 17:20:14-07:00
# 2        2015-08-14 17:30:15-07:00
# 3        2015-08-14 17:40:16-07:00
# 4        2015-08-14 17:50:17-07:00
#                    ...
# 62179    2017-03-18 18:42:28-07:00
# 62180    2017-03-18 18:52:35-07:00
# 62181    2017-03-18 19:02:40-07:00
# 62182    2017-03-18 19:12:47-07:00
# 62183    2017-03-18 19:22:51-07:00
# Name: date, Length: 62184, dtype: object

# %%
df["date"] = pd.to_datetime(df["date"],utc=True)

# %%
df["year"] = df["date"].dt.year

# %%
df.drop("date",axis=1,inplace=True)

# %%
df.head()
# Out:
#    number_people  timestamp  day_of_week  is_weekend  is_holiday  temperature  \
# 0             37      61211            4           0           0        71.76
# 1             45      62414            4           0           0        71.76
# 2             40      63015            4           0           0        71.76
# 3             44      63616            4           0           0        71.76
# 4             45      64217            4           0           0        71.76
#
#    is_start_of_semester  is_during_semester  month  hour  year
# 0                     0                   0      8    17  2015
# 1                     0                   0      8    17  2015
# 2                     0                   0      8    17  2015
# 3                     0                   0      8    17  2015
# 4                     0                   0      8    17  2015

# %%
df["year"].unique()
# Out:
# array([2015, 2016, 2017], dtype=int32)

# %%
sns.lineplot(data=df,x=df["hour"],y=df["number_people"])
plt.title("Number of People in the Gym by Hour")
plt.show()

# %%
sns.boxplot(data=df, x="hour", y="number_people")
plt.xticks(rotation=90)
plt.title("Hourly Distribution of Gym Occupancy")
plt.show()

# %%
sns.boxplot(x=df["is_holiday"],y=df["number_people"])
plt.show()

# %%
sns.boxplot(x=df["is_during_semester"],y=df["number_people"])
plt.show()

# %%
sns.boxplot(x=df["is_weekend"],y=df["number_people"])
plt.show()

# %%
sns.barplot(data=df, x="day_of_week", y="number_people")
plt.title("Average Gym Occupancy by Day of Week")
plt.show()

# %%
sns.boxplot(data=df, x="is_weekend", y="number_people")
plt.title("Gym Occupancy: Weekday vs Weekend")
plt.show()

# %%
sns.lineplot(data=df, x="month", y="number_people")
plt.title("Monthly Gym Occupancy Trend")
plt.show()

# %%
plt.figure(figsize=(10,6))

sns.scatterplot(
    data=df,
    x="temperature",
    y="number_people",
    alpha=0.5
)

plt.title("Gym Occupancy vs Temperature", fontsize=14)
plt.xlabel("Temperature")
plt.ylabel("Number of People")
plt.grid(True, linestyle="--", alpha=0.3)

plt.show()

# %%
corr = df.corr()

sns.heatmap(corr, annot=True, cmap="coolwarm")
plt.title("Feature Correlation Matrix")
plt.show()

# %%
df.corr()
# Out:
#                       number_people  timestamp  day_of_week  is_weekend  \
# number_people              1.000000   0.550218    -0.162062   -0.173958
# timestamp                  0.550218   1.000000    -0.001793   -0.000509
# day_of_week               -0.162062  -0.001793     1.000000    0.791338
# is_weekend                -0.173958  -0.000509     0.791338    1.000000
# is_holiday                -0.048249   0.002851    -0.075862   -0.031899
# temperature                0.373327   0.184849     0.011169    0.020673
# is_start_of_semester       0.182683   0.009551    -0.011782   -0.016646
# is_during_semester         0.335350   0.044676    -0.004824   -0.036127
# month                     -0.097854  -0.023221     0.015559    0.008462
# hour                       0.552049   0.999077    -0.001914   -0.000517
# year                      -0.322591  -0.077767    -0.021242   -0.021260
#
#                       is_holiday  temperature  is_start_of_semester  \
# ...

# %%
df.drop("timestamp",axis=1,inplace=True)

# %%
df.head()
# Out:
#    number_people  day_of_week  is_weekend  is_holiday  temperature  \
# 0             37            4           0           0        71.76
# 1             45            4           0           0        71.76
# 2             40            4           0           0        71.76
# 3             44            4           0           0        71.76
# 4             45            4           0           0        71.76
#
#    is_start_of_semester  is_during_semester  month  hour  year
# 0                     0                   0      8    17  2015
# 1                     0                   0      8    17  2015
# 2                     0                   0      8    17  2015
# 3                     0                   0      8    17  2015
# 4                     0                   0      8    17  2015

# %%
X = df.drop('number_people',axis=1)
y = df["number_people"]

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.3,random_state=42)

# %%
from sklearn.linear_model import LinearRegression,Ridge,Lasso,ElasticNet
from sklearn.ensemble import RandomForestRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import r2_score,mean_absolute_error,mean_squared_error

# %%
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %%
def calculate_model_metrics(true, predicted):
    mae = mean_absolute_error(true, predicted)
    mse = mean_squared_error(true, predicted)
    rmse = np.sqrt(mean_squared_error(true, predicted))
    r2_square = r2_score(true, predicted)

    return mae,rmse,r2_square

# %%
models = {
    "linear" : LinearRegression(),
    "ridge" : Ridge(),
    "lasso" : Lasso(),
    "elasticnet" : ElasticNet(),
    "decision_tree" : DecisionTreeRegressor(),
    "K_Neighbors" : KNeighborsRegressor(),
    "Random Forest Regressor" : RandomForestRegressor()
}

# %%
for i in range(len(list(models))):
    model = list(models.values())[i]
    model.fit(X_train,y_train)

    y_train_pred = model.predict(X_train)
    y_test_pred = model.predict(X_test)

    model_train_mae,model_train_rmse,model_train_r2 = calculate_model_metrics(y_train,y_train_pred)
    model_test_mae,model_test_rmse,model_test_r2 = calculate_model_metrics(y_test,y_test_pred)

    print(list(models.values())[i])
    print("Evaluation for Training Set")
    print("RMSE :",model_train_rmse)
    print("MAE :",model_train_mae)
    print("R2 Score :",model_train_r2)

    print("--------------------------------")
    
    print("Evaluation for Test Set")
    print("RMSE :",model_test_rmse)
    print("MAE :",model_test_mae)
    print("R2 Score :",model_test_r2)

    print("--------------------------------")
    print("\n")
# Out:
# LinearRegression()
# Evaluation for Training Set
# RMSE : 14.369577810199202
# MAE : 10.747737402554746
# R2 Score : 0.5986558451652864
# --------------------------------
# Evaluation for Test Set
# RMSE : 14.320719507760078
# MAE : 10.709154130154474
# R2 Score : 0.602118663461176
# --------------------------------
#
#
# Ridge()
# Evaluation for Training Set
# RMSE : 14.369577816718996
# MAE : 10.747745480342564
# R2 Score : 0.598655844801089
# --------------------------------
# Evaluation for Test Set
# RMSE : 14.320715104397038
# MAE : 10.70916308847512
# R2 Score : 0.6021189081438125
# --------------------------------
#
#
# Lasso()
# Evaluation for Training Set
# RMSE : 14.616108706983828
# MAE : 10.949481415912425
# R2 Score : 0.5847664327991025
# --------------------------------
# Evaluation for Test Set
# RMSE : 14.5669227135107
# MAE : 10.926322505409685
# R2 Score : 0.5883202329385491
# --------------------------------
#
#
# ElasticNet()
# Evaluation for Training Set
# ...

# %%
knn_params = {"n_neighbors" : [2,3,4,5,10,20,30,40]}

rf_params = {
    "max_depth" : [4,5,8,10,15,None],
    "max_features" : ["sqrt","log2",5,7,10],
    "min_samples_split" : [2,4,8,12,20],
    "n_estimators" : [100,200,500,1000]
}

dt_params = {
    "criterion": ["squared_error", "absolute_error", "friedman_mse"],
    "splitter": ["best", "random"],
    "max_depth": [4, 5, 8, 10, 15, None],
    "min_samples_split": [2, 4, 8, 12, 20],
    "max_features": ["sqrt", "log2", None]
}

# %%
from sklearn.model_selection import RandomizedSearchCV

# %%
randomcv_models = [
    ("KNN", KNeighborsRegressor(), knn_params),
    ("RF", RandomForestRegressor(),rf_params),
    ("DT", DecisionTreeRegressor(),dt_params)
]

# %%
for name, model, params in randomcv_models:
    randomcv = RandomizedSearchCV(estimator=model, param_distributions=params, n_iter=100, cv=5,n_jobs=-1)
    randomcv.fit(X_train,y_train)
    print("best params for : ",name, randomcv.best_params_)
# Out:
# C:\Users\ultra\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\model_selection\_search.py:317: UserWarning: The total space of parameters 8 is smaller than n_iter=100. Running 8 iterations. For exhaustive searches, use GridSearchCV.
#   warnings.warn(
# best params for :  KNN {'n_neighbors': 2}
# best params for :  RF {'n_estimators': 1000, 'min_samples_split': 4, 'max_features': 5, 'max_depth': None}
# best params for :  DT {'splitter': 'random', 'min_samples_split': 2, 'max_features': 'sqrt', 'max_depth': None, 'criterion': 'squared_error'}

# %%
models = {
    "K_Neighbors" : KNeighborsRegressor(),
    "Random Forest Regressor" : RandomForestRegressor(),
    "decision_tree" : DecisionTreeRegressor()
}

# %%
for i in range(len(list(models))):
    model = list(models.values())[i]
    model.fit(X_train,y_train)

    y_train_pred = model.predict(X_train)
    y_test_pred = model.predict(X_test)

    model_train_mae,model_train_rmse,model_train_r2 = calculate_model_metrics(y_train,y_train_pred)
    model_test_mae,model_test_rmse,model_test_r2 = calculate_model_metrics(y_test,y_test_pred)

    print(list(models.values())[i])
    print("Evaluation for Training Set")
    print("RMSE :",model_train_rmse)
    print("MAE :",model_train_mae)
    print("R2 Score :",model_train_r2)

    print("--------------------------------")
    
    print("Evaluation for Test Set")
    print("RMSE :",model_test_rmse)
    print("MAE :",model_test_mae)
    print("R2 Score :",model_test_r2)

    print("--------------------------------")
    print("\n")
# Out:
# KNeighborsRegressor()
# Evaluation for Training Set
# RMSE : 5.596550746752989
# MAE : 3.7509740856460216
# R2 Score : 0.9391206765243483
# --------------------------------
# Evaluation for Test Set
# RMSE : 7.29607747830766
# MAE : 4.898359777015437
# R2 Score : 0.8967232017912736
# --------------------------------
#
#
# RandomForestRegressor()
# Evaluation for Training Set
# RMSE : 4.706905503830778
# MAE : 3.194533172796477
# R2 Score : 0.9569374360260343
# --------------------------------
# Evaluation for Test Set
# RMSE : 6.35998313385613
# MAE : 4.297695321932444
# R2 Score : 0.9215241878479651
# --------------------------------
#
#
# DecisionTreeRegressor()
# Evaluation for Training Set
# RMSE : 4.665769568489102
# MAE : 3.147715735581276
# R2 Score : 0.9576868363276235
# --------------------------------
# Evaluation for Test Set
# RMSE : 6.50219803933014
# MAE : 4.355248241200369
# R2 Score : 0.9179753706372014
# --------------------------------
